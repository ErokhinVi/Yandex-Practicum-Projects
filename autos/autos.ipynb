# %% [markdown]
# # Описание проекта
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение, чтобы привлечь новых клиентов. В нём можно будет узнать рыночную стоимость своего автомобиля.
#
# Постройте модель, которая умеет её определять. В вашем распоряжении данные о технических характеристиках, комплектации и ценах других автомобилей.
#
# Критерии, которые важны заказчику:
#  - качество предсказания;
#  - время обучения модели;
#  - время предсказания модели.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.dummy import DummyRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
import random
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np
from tqdm import tqdm
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Загрузка данных

# %%
try:
    df = pd.read_csv('H:/autos.csv')
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/autos.csv')

# %%
df.head()
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500       small              2001  manual     75
# 4  2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0   golf     150000                  0    petrol  volkswagen      NaN
# 1    NaN     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep      NaN
# 3   golf     150000                  6    petrol  volkswagen       no
# 4  fabia      90000                  7  gasoline       skoda       no
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00                 0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00                 0       60437  2016-04-06 10:17:21

# %%
old_shape = df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  Repaired           283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %% [markdown]
# Использовав метод `info` можем увидеть что названия столбцов имеют не корректный вид. Поэтому приведём все названия столбцов к нижнему регистру и разделим слова чертами
#
# Также можно отметить что все столбцы имеют корректный тип данных

# %%
df.columns = map(str.lower, df.columns)

# %%
df.rename({'datecrawled': 'date_crawled',
           'vehicletype': 'vehicle_type',
           'registrationyear': 'registration_year',
           'gearbox': 'gear_box',
           'regisrationmonth': 'registration_month',
           'fueltype': 'fuel_type',
           'numberofpictures': 'number_of_pictures',
           'postalcode': 'postal_code',
           'lastseen': 'last_seen',
           'datecreated': 'date_created',
           'registrationmonth': 'registration_month'
           }, axis=1, inplace=True)

# %% [markdown]
# Найдём количество пропусков в столбцах. Пропуски имеют только категориальные столбцы.

# %%
df.isna().sum()
# Out:
# date_crawled              0
# price                     0
# vehicle_type          37490
# registration_year         0
# gear_box              19833
# power                     0
# model                 19705
# kilometer                 0
# registration_month        0
# fuel_type             32895
# brand                     0
# repaired              71154
# date_created              0
# number_of_pictures        0
# postal_code               0
# last_seen                 0
# dtype: int64

# %% [markdown]
# # Исследовательский анализ даных

# %% [markdown]
# Построим матрицу корреляций для количественных признаков.

# %%
px.imshow(df.corr().drop('number_of_pictures', axis=1).
                    drop('number_of_pictures', axis=0),text_auto=True)

# %% [markdown]
# Исходя из матрицы корреляции можно увидеть , что ни один из количественных признаков не имеет сильной зависимости от какого-либо другого признака.

# %% [markdown]
# Построим гистограммы для количественных признаков, чтобы посмотреть на их распределения

# %%
def histg(column_name):
    fig = go.Figure()

    fig.add_trace(
        go.Histogram(x=df[column_name], autobinx=True, opacity=.8)
    )
    fig.update_layout(
        title={
            'text': column_name,
            'y': 0.9,
            'x': 0.5,
            'xanchor': 'center',
            'yanchor': 'top'})
    fig.show()

# %%
for name in ['price','registration_year','power','kilometer','registration_month','number_of_pictures']:
    histg(name)

# %% [markdown]
# Анализируя графики видно, что:
#  - `price` - Имеет большое количество выбросов до 400 евро, такая цена машины совсем не реалистична для современного мира.\
#  - `registration_year` - Имеет небольшое кол-во выбросов вне промежутка (1975 - 2020 г.)\
#  Медианное значение года регистрации - 2004 г.
#  - `power` - Имеет большое количество выбросов мощностью до 30 л.с или более 1200 л.с, что также не реалистично относительно современных машин.
#  - `kilometer` - Имеет наибольшее кол-во объявлений для машин чей пробег ~ 150000 км.
#  - `registration month` - Стремится к константному распределению
#  - `number_of_pictures` - Ни в одном из объявлений нет фотографий, поэтому данный признак будет не информативен для дальнейшего использования

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Заменим аномальные значения в столбцах `power`, `registration_year`,`price`:
#  - `power` - Замена с помощью медианного значения промежутка (30-1200 л.с)
#  - `registration_year` - Замена с помощью медианного значения всего столбца
#  - `price` - Так как цена является целевым признаком, то для точности анализа избавимся от строк содержащих аномальную цену

# %%
power_medi = df.loc[(df.power > 30) & (df.power < 1200), 'power'].median()

df['power'] = np.where(
    (df['power'] >= 1200) | (df['power'] < 30), power_medi, df['power']
)

# %%
year_medi = df['registration_year'].median()

df['registration_year'] = np.where(
    (df['registration_year'] >= 2016) | (
        df['registration_year'] < 1975), year_medi, df['registration_year']
)

# %% [markdown]
# ![Img.png](attachment:Img.png)

# %%
df.drop(index=df[df.price <= 400].index, inplace=True, axis=0)

# %% [markdown]
# Посмотрим на распределение категориальных признаков в которых есть пропуски:

# %%
cat_list = ['vehicle_type', 'gear_box',
                    'model', 'fuel_type', 'repaired','brand']
# for name in cat_list:
#     fig = px.bar(y=df[name].value_counts(), x=df[name].value_counts(
#     ).index, text_auto=True, opacity=.8, labels={'x': name, 'y': 'Количество'})
#     fig.show()

# %% [markdown]
# Для того, чтобы избежать удаления данных значений и искажения их исходных распределений - заполним пропуски случайными значениями из своего столбца соответственно.

# %%
df.fillna('unknown',inplace=True)

# %% [markdown]
# Создадим копию датасета для работы моделей с категориальными признаками, а также "дропнем" неинформативные столбцы

# %%
df_cat = df.copy()
df_cat.loc[:,cat_list] = df_cat[cat_list].astype('category')
df_cat.drop(['postal_code', 'date_crawled', 'date_created', 'last_seen',
             'number_of_pictures'], axis=1, inplace=True)

# %%
df.reset_index(drop='first',inplace=True)
df.drop(['postal_code', 'date_crawled',
        'number_of_pictures'], axis=1, inplace=True)

# %% [markdown]
# Приведём столбцы с датами к типу данных `datetime`

# %%
df[['date_created', 'last_seen']] = df[[
    'date_created', 'last_seen']].apply(pd.to_datetime)

# %% [markdown]
# Создадим функцию которая будет кластеризировать столбец с датами на 3 группы (LabelEncode):
#  - `0` - Поздняя дата
#  - `1` - Недавняя дата
#  - `2` - Свежая дата

# %%
def LabelEncodeDateIndex(df, column_name):
    late_index = df[column_name].sort_values(
    )[:round(len(df[column_name])/3)].index
    middle_index = df[column_name].sort_values()[round(
        len(df[column_name])/3):round(len(df[column_name])*2/3)].index
    early_index = df[column_name].sort_values()[round(
        len(df[column_name])*2/3):round(len(df[column_name]))].index

    df.loc[late_index, column_name] = 0
    df.loc[middle_index, column_name] = 1
    df.loc[early_index, column_name] = 2
    df[column_name] = df[column_name].astype(int)

# %%
LabelEncodeDateIndex(df, 'date_created')
LabelEncodeDateIndex(df, 'last_seen')

# %% [markdown]
# В итоге после предобработки потеряли чуть больше 9% данных что не должно существенно сказаться на предсказании

# %%
(1-df.shape[0]/old_shape[0])*100
# Out:
# 9.16022564050467

# %% [markdown]
# #  Модели машинного обучения

# %% [markdown]
# Разделим выборки на тренировочную и тестовую, на признаки и целевые признаки

# %%
features = df.drop('price', axis=1).reset_index(drop='first')
target = df.price.reset_index(drop='first')

train_features, test_features, train_target, test_target = train_test_split(
    features, target, test_size=.25, random_state=42)

# %%
features_cat = df_cat.drop('price', axis=1).reset_index(drop='first')
target_cat = df_cat.price.reset_index(drop='first')

train_features_cat, test_features_cat, train_target_cat, test_target_cat = train_test_split(
    features_cat, target_cat, test_size=.25, random_state=42)

# %%
enc = OneHotEncoder(sparse=False,drop='first')
enc.fit(train_features[cat_list])
enc_train_features = enc.transform(train_features[cat_list])
enc_test_features = enc.transform(test_features[cat_list])

# %%
train_features.reset_index(drop='first',inplace=True)
train_features = train_features.join(pd.DataFrame(
    enc_train_features, columns=enc.get_feature_names())).drop(cat_list, axis=1)

test_features.reset_index(drop='first',inplace=True)
test_features = test_features.join(pd.DataFrame(
    enc_test_features, columns=enc.get_feature_names())).drop(cat_list, axis=1)

# %%
print(
    f'Количество строк тренировочной выборки: {train_features.shape[0]}:{train_target.shape[0]}')
print(
    f'Количество строк тестовой выборки: {test_features.shape[0]}:{test_target.shape[0]}')
# Out:
# Количество строк тренировочной выборки: 241431:241431
# Количество строк тестовой выборки: 80477:80477

# %% [markdown]
# Создадим функцию, которая будет обучать модель на CV,добиваясь наилучшего score на метрике RMSE, а также строить график `feature importance`, чтобы отслеживать какая из "фичей" влияет больше всего на метрику.

# %%
def teach_model(model, parameters, features, target,time_list):
    grid = GridSearchCV(model, parameters, n_jobs=-1,
                        scoring='neg_root_mean_squared_error')
    grid.fit(features, target)
    print(-grid.best_score_)
    print(grid.best_params_)

    try:
        feature_importance = grid.best_estimator_.feature_importances_
        sorted_idx = np.argsort(feature_importance)
        fig = plt.figure(figsize=(12, 50))
        plt.barh(range(len(sorted_idx)),
                 feature_importance[sorted_idx], align='center')
        plt.yticks(range(len(sorted_idx)), np.array(
            features.columns)[sorted_idx])
        plt.title('Feature Importance')
        fig.show()
    except:
        pass
    
    time_list.append([grid.cv_results_['mean_fit_time'][0],grid.cv_results_['mean_score_time'][0],-grid.best_score_])

    return grid.best_estimator_

# %%
time_list = []

# %%
# %%time
model = DecisionTreeRegressor(random_state=42)
parameters = {'max_depth': range(2, 7, 1), 'min_samples_split': [
    2, 3], 'min_samples_leaf': [1, 2]}
best_dt = teach_model(model, parameters, train_features, train_target,time_list)
# Out:
# 2348.0168729780466
# {'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2}
# CPU times: total: 4.7 s
# Wall time: 56.3 s

# %%
# %%time
# model = CatBoostRegressor(task_type='CPU', random_state=42,cat_features=cat_list)
# parameters = {'iterations': range(
#     100, 1001, 100), 'learning_rate': [.1, .5, .8]}
# best_cb = teach_model(model, parameters, train_features_cat, train_target_cat)

# %%
# %%time
model = CatBoostRegressor(task_type='CPU', random_state=42)
parameters = {'iterations': range(
    100, 1001, 100), 'learning_rate': [.1, .5, .8]}
best_cb = teach_model(model, parameters, train_features, train_target,time_list)
# Out:
# 0:	learn: 3199.8758832	total: 160ms	remaining: 2m 40s
# 1:	learn: 2648.2602500	total: 172ms	remaining: 1m 26s
# 2:	learn: 2402.8487999	total: 181ms	remaining: 1m
# 3:	learn: 2280.3375020	total: 192ms	remaining: 47.8s
# 4:	learn: 2204.6612854	total: 202ms	remaining: 40.2s
# 5:	learn: 2150.4016570	total: 212ms	remaining: 35.2s
# 6:	learn: 2110.1471902	total: 223ms	remaining: 31.6s
# 7:	learn: 2079.1601376	total: 233ms	remaining: 28.8s
# 8:	learn: 2051.3967738	total: 244ms	remaining: 26.9s
# 9:	learn: 2028.9030984	total: 254ms	remaining: 25.2s
# 10:	learn: 2014.0219665	total: 265ms	remaining: 23.8s
# 11:	learn: 1999.2619717	total: 277ms	remaining: 22.8s
# 12:	learn: 1988.2561583	total: 287ms	remaining: 21.8s
# 13:	learn: 1978.2522138	total: 298ms	remaining: 21s
# 14:	learn: 1962.3523756	total: 308ms	remaining: 20.2s
# 15:	learn: 1949.5965874	total: 319ms	remaining: 19.6s
# 16:	learn: 1942.9225312	total: 330ms	remaining: 19.1s
# 17:	learn: 1930.8531504	total: 342ms	remaining: 18.7s
# 18:	learn: 1924.9326712	total: 352ms	remaining: 18.2s
# 19:	learn: 1912.5026247	total: 363ms	remaining: 17.8s
# 20:	learn: 1900.1573021	total: 373ms	remaining: 17.4s
# 21:	learn: 1895.4272495	total: 384ms	remaining: 17.1s
# 22:	learn: 1889.0796617	total: 395ms	remaining: 16.8s
# 23:	learn: 1883.3849460	total: 406ms	remaining: 16.5s
# 24:	learn: 1874.6002475	total: 418ms	remaining: 16.3s
# 25:	learn: 1871.1543940	total: 429ms	remaining: 16.1s
# 26:	learn: 1865.3167517	total: 441ms	remaining: 15.9s
# 27:	learn: 1858.0696587	total: 452ms	remaining: 15.7s
# 28:	learn: 1852.4085646	total: 462ms	remaining: 15.5s
# 29:	learn: 1846.5203369	total: 473ms	remaining: 15.3s
# 30:	learn: 1841.6756523	total: 484ms	remaining: 15.1s
# 31:	learn: 1836.3902201	total: 495ms	remaining: 15s
# 32:	learn: 1832.1835283	total: 506ms	remaining: 14.8s
# 33:	learn: 1825.4109317	total: 515ms	remaining: 14.6s
# 34:	learn: 1821.9931924	total: 527ms	remaining: 14.5s
# 35:	learn: 1819.4451140	total: 538ms	remaining: 14.4s
# 36:	learn: 1816.4419867	total: 550ms	remaining: 14.3s
# 37:	learn: 1812.2728357	total: 561ms	remaining: 14.2s
# 38:	learn: 1808.8919169	total: 573ms	remaining: 14.1s
# 39:	learn: 1806.6449481	total: 584ms	remaining: 14s
# 40:	learn: 1802.6293716	total: 595ms	remaining: 13.9s
# 41:	learn: 1798.7611637	total: 605ms	remaining: 13.8s
# 42:	learn: 1794.8020083	total: 617ms	remaining: 13.7s
# 43:	learn: 1792.3392098	total: 628ms	remaining: 13.7s
# 44:	learn: 1788.6552461	total: 639ms	remaining: 13.6s
# 45:	learn: 1786.3241981	total: 651ms	remaining: 13.5s
# 46:	learn: 1781.9781532	total: 663ms	remaining: 13.4s
# 47:	learn: 1778.6791017	total: 672ms	remaining: 13.3s
# 48:	learn: 1776.1377197	total: 683ms	remaining: 13.3s
# 49:	learn: 1773.9085346	total: 694ms	remaining: 13.2s
# 50:	learn: 1771.0721175	total: 705ms	remaining: 13.1s
# 51:	learn: 1767.3506721	total: 715ms	remaining: 13s
# 52:	learn: 1765.3252724	total: 726ms	remaining: 13s
# 53:	learn: 1763.1375079	total: 738ms	remaining: 12.9s
# 54:	learn: 1761.0727809	total: 749ms	remaining: 12.9s
# 55:	learn: 1759.2649206	total: 760ms	remaining: 12.8s
# 56:	learn: 1756.9146273	total: 772ms	remaining: 12.8s
# 57:	learn: 1755.5242963	total: 783ms	remaining: 12.7s
# 58:	learn: 1753.6994886	total: 795ms	remaining: 12.7s
# 59:	learn: 1750.2886784	total: 805ms	remaining: 12.6s
# 60:	learn: 1747.7448188	total: 815ms	remaining: 12.5s
# 61:	learn: 1745.7415449	total: 826ms	remaining: 12.5s
# 62:	learn: 1744.1130184	total: 837ms	remaining: 12.5s
# 63:	learn: 1742.6539884	total: 848ms	remaining: 12.4s
# 64:	learn: 1739.4075350	total: 858ms	remaining: 12.3s
# 65:	learn: 1736.7264537	total: 868ms	remaining: 12.3s
# 66:	learn: 1734.9540243	total: 878ms	remaining: 12.2s
# 67:	learn: 1733.4644663	total: 889ms	remaining: 12.2s
# 68:	learn: 1732.1386551	total: 901ms	remaining: 12.2s
# 69:	learn: 1729.1830259	total: 912ms	remaining: 12.1s
# 70:	learn: 1727.3136256	total: 924ms	remaining: 12.1s
# 71:	learn: 1725.4754497	total: 933ms	remaining: 12s
# 72:	learn: 1724.1898816	total: 944ms	remaining: 12s
# 73:	learn: 1722.2118693	total: 955ms	remaining: 11.9s
# 74:	learn: 1720.4396511	total: 965ms	remaining: 11.9s
# 75:	learn: 1719.3918536	total: 976ms	remaining: 11.9s
# 76:	learn: 1717.4371657	total: 987ms	remaining: 11.8s
# 77:	learn: 1715.7639146	total: 998ms	remaining: 11.8s
# 78:	learn: 1713.9662615	total: 1.01s	remaining: 11.8s
# 79:	learn: 1712.1986489	total: 1.02s	remaining: 11.7s
# 80:	learn: 1710.8657644	total: 1.03s	remaining: 11.7s
# 81:	learn: 1709.8628397	total: 1.04s	remaining: 11.7s
# 82:	learn: 1709.0015613	total: 1.05s	remaining: 11.6s
# 83:	learn: 1707.8705472	total: 1.06s	remaining: 11.6s
# 84:	learn: 1706.0961799	total: 1.07s	remaining: 11.6s
# 85:	learn: 1704.2450568	total: 1.08s	remaining: 11.5s
# 86:	learn: 1702.6824234	total: 1.09s	remaining: 11.5s
# 87:	learn: 1701.4743840	total: 1.11s	remaining: 11.5s
# 88:	learn: 1700.3029596	total: 1.12s	remaining: 11.4s
# 89:	learn: 1699.2860643	total: 1.13s	remaining: 11.4s
# 90:	learn: 1697.9875115	total: 1.14s	remaining: 11.4s
# 91:	learn: 1696.7206301	total: 1.15s	remaining: 11.4s
# 92:	learn: 1695.1689701	total: 1.16s	remaining: 11.3s
# 93:	learn: 1693.5272219	total: 1.17s	remaining: 11.3s
# 94:	learn: 1692.1157145	total: 1.18s	remaining: 11.3s
# 95:	learn: 1690.9049762	total: 1.19s	remaining: 11.2s
# 96:	learn: 1689.1335070	total: 1.21s	remaining: 11.2s
# 97:	learn: 1687.6901495	total: 1.22s	remaining: 11.2s
# 98:	learn: 1686.5145435	total: 1.23s	remaining: 11.2s
# 99:	learn: 1685.4138549	total: 1.24s	remaining: 11.2s
# 100:	learn: 1683.7597458	total: 1.25s	remaining: 11.1s
# 101:	learn: 1682.0081918	total: 1.26s	remaining: 11.1s
# 102:	learn: 1680.9552844	total: 1.27s	remaining: 11.1s
# 103:	learn: 1679.7657760	total: 1.28s	remaining: 11.1s
# 104:	learn: 1678.7630801	total: 1.29s	remaining: 11s
# 105:	learn: 1678.1990652	total: 1.3s	remaining: 11s
# 106:	learn: 1676.3356368	total: 1.31s	remaining: 11s
# 107:	learn: 1675.0802602	total: 1.32s	remaining: 10.9s
# 108:	learn: 1673.0009373	total: 1.33s	remaining: 10.9s
# 109:	learn: 1671.5336830	total: 1.35s	remaining: 10.9s
# 110:	learn: 1670.8955184	total: 1.36s	remaining: 10.9s
# 111:	learn: 1669.8920734	total: 1.37s	remaining: 10.8s
# 112:	learn: 1668.9176327	total: 1.38s	remaining: 10.8s
# 113:	learn: 1668.2330587	total: 1.39s	remaining: 10.8s
# 114:	learn: 1667.2505532	total: 1.4s	remaining: 10.8s
# 115:	learn: 1665.0516426	total: 1.41s	remaining: 10.8s
# 116:	learn: 1663.7794538	total: 1.43s	remaining: 10.8s
# 117:	learn: 1662.5149244	total: 1.44s	remaining: 10.7s
# 118:	learn: 1660.6667976	total: 1.45s	remaining: 10.7s
# 119:	learn: 1659.8326709	total: 1.46s	remaining: 10.7s
# 120:	learn: 1658.6737327	total: 1.47s	remaining: 10.7s
# 121:	learn: 1657.8028864	total: 1.48s	remaining: 10.7s
# 122:	learn: 1657.0006257	total: 1.5s	remaining: 10.7s
# 123:	learn: 1656.1090656	total: 1.51s	remaining: 10.7s
# 124:	learn: 1655.3471907	total: 1.52s	remaining: 10.6s
# 125:	learn: 1654.3457885	total: 1.53s	remaining: 10.6s
# 126:	learn: 1653.2528516	total: 1.54s	remaining: 10.6s
# 127:	learn: 1652.4009820	total: 1.55s	remaining: 10.6s
# 128:	learn: 1651.4347302	total: 1.56s	remaining: 10.6s
# 129:	learn: 1650.6707144	total: 1.57s	remaining: 10.5s
# 130:	learn: 1648.8366237	total: 1.58s	remaining: 10.5s
# 131:	learn: 1647.8743193	total: 1.59s	remaining: 10.5s
# 132:	learn: 1646.7437371	total: 1.6s	remaining: 10.5s
# 133:	learn: 1645.8870210	total: 1.62s	remaining: 10.5s
# 134:	learn: 1645.2704289	total: 1.63s	remaining: 10.4s
# 135:	learn: 1644.6593674	total: 1.64s	remaining: 10.4s
# 136:	learn: 1643.6541831	total: 1.65s	remaining: 10.4s
# 137:	learn: 1642.5850241	total: 1.66s	remaining: 10.4s
# 138:	learn: 1641.8955230	total: 1.67s	remaining: 10.4s
# 139:	learn: 1641.2293392	total: 1.69s	remaining: 10.4s
# 140:	learn: 1640.5946863	total: 1.7s	remaining: 10.3s
# 141:	learn: 1639.8524287	total: 1.71s	remaining: 10.3s
# 142:	learn: 1638.7243548	total: 1.72s	remaining: 10.3s
# 143:	learn: 1638.1529273	total: 1.73s	remaining: 10.3s
# 144:	learn: 1637.3046815	total: 1.74s	remaining: 10.3s
# 145:	learn: 1636.5952913	total: 1.75s	remaining: 10.3s
# 146:	learn: 1635.9881279	total: 1.77s	remaining: 10.2s
# 147:	learn: 1635.5019472	total: 1.78s	remaining: 10.2s
# 148:	learn: 1634.7797593	total: 1.79s	remaining: 10.2s
# 149:	learn: 1633.8613671	total: 1.8s	remaining: 10.2s
# 150:	learn: 1633.2000066	total: 1.81s	remaining: 10.2s
# 151:	learn: 1631.9627406	total: 1.82s	remaining: 10.2s
# 152:	learn: 1631.4393669	total: 1.83s	remaining: 10.2s
# 153:	learn: 1630.9578292	total: 1.85s	remaining: 10.1s
# 154:	learn: 1629.9462888	total: 1.86s	remaining: 10.1s
# 155:	learn: 1629.1870277	total: 1.87s	remaining: 10.1s
# 156:	learn: 1628.4056459	total: 1.88s	remaining: 10.1s
# 157:	learn: 1627.0291465	total: 1.89s	remaining: 10.1s
# 158:	learn: 1625.7843163	total: 1.9s	remaining: 10.1s
# 159:	learn: 1625.2571531	total: 1.91s	remaining: 10s
# 160:	learn: 1624.5144931	total: 1.92s	remaining: 10s
# 161:	learn: 1623.4634278	total: 1.93s	remaining: 10s
# 162:	learn: 1622.7172492	total: 1.94s	remaining: 9.99s
# 163:	learn: 1622.4115144	total: 1.95s	remaining: 9.96s
# 164:	learn: 1621.6715327	total: 1.96s	remaining: 9.94s
# 165:	learn: 1620.7558102	total: 1.97s	remaining: 9.92s
# 166:	learn: 1619.7456846	total: 1.98s	remaining: 9.9s
# 167:	learn: 1618.9373896	total: 2s	remaining: 9.89s
# 168:	learn: 1618.1116067	total: 2.01s	remaining: 9.87s
# 169:	learn: 1617.1738487	total: 2.02s	remaining: 9.86s
# 170:	learn: 1616.6876692	total: 2.03s	remaining: 9.84s
# 171:	learn: 1616.1876160	total: 2.04s	remaining: 9.82s
# 172:	learn: 1615.5578278	total: 2.05s	remaining: 9.8s
# 173:	learn: 1614.4465458	total: 2.06s	remaining: 9.79s
# 174:	learn: 1613.6253768	total: 2.07s	remaining: 9.76s
# 175:	learn: 1612.9170770	total: 2.08s	remaining: 9.74s
# 176:	learn: 1612.2436457	total: 2.09s	remaining: 9.73s
# 177:	learn: 1611.0493409	total: 2.1s	remaining: 9.71s
# 178:	learn: 1610.2253088	total: 2.11s	remaining: 9.7s
# 179:	learn: 1609.5397986	total: 2.12s	remaining: 9.68s
# 180:	learn: 1609.1682037	total: 2.14s	remaining: 9.67s
# 181:	learn: 1608.3066975	total: 2.15s	remaining: 9.65s
# 182:	learn: 1607.6073951	total: 2.16s	remaining: 9.63s
# 183:	learn: 1605.9215328	total: 2.17s	remaining: 9.62s
# 184:	learn: 1605.5294265	total: 2.18s	remaining: 9.61s
# 185:	learn: 1604.5760525	total: 2.19s	remaining: 9.59s
# 186:	learn: 1604.0883774	total: 2.2s	remaining: 9.58s
# 187:	learn: 1603.5326552	total: 2.21s	remaining: 9.57s
# 188:	learn: 1602.8061092	total: 2.23s	remaining: 9.55s
# 189:	learn: 1602.3539647	total: 2.24s	remaining: 9.54s
# 190:	learn: 1601.8952013	total: 2.25s	remaining: 9.52s
# 191:	learn: 1601.5213264	total: 2.26s	remaining: 9.51s
# 192:	learn: 1600.8412794	total: 2.27s	remaining: 9.49s
# 193:	learn: 1600.2660477	total: 2.28s	remaining: 9.48s
# 194:	learn: 1599.9193961	total: 2.29s	remaining: 9.46s
# 195:	learn: 1599.1090430	total: 2.3s	remaining: 9.45s
# 196:	learn: 1598.2296829	total: 2.31s	remaining: 9.43s
# 197:	learn: 1597.7027099	total: 2.33s	remaining: 9.42s
# 198:	learn: 1597.3817698	total: 2.34s	remaining: 9.4s
# 199:	learn: 1596.8285324	total: 2.35s	remaining: 9.39s
# 200:	learn: 1596.2570799	total: 2.36s	remaining: 9.37s
# 201:	learn: 1595.4257671	total: 2.37s	remaining: 9.36s
# 202:	learn: 1594.7022981	total: 2.38s	remaining: 9.34s
# 203:	learn: 1594.1053645	total: 2.39s	remaining: 9.33s
# 204:	learn: 1593.5600573	total: 2.4s	remaining: 9.31s
# 205:	learn: 1593.1362905	total: 2.41s	remaining: 9.3s
# 206:	learn: 1591.9695168	total: 2.42s	remaining: 9.28s
# 207:	learn: 1591.5678460	total: 2.43s	remaining: 9.27s
# 208:	learn: 1590.8461527	total: 2.44s	remaining: 9.25s
# 209:	learn: 1590.2628062	total: 2.46s	remaining: 9.24s
# 210:	learn: 1589.5223136	total: 2.47s	remaining: 9.23s
# 211:	learn: 1589.0087462	total: 2.48s	remaining: 9.22s
# 212:	learn: 1588.5407447	total: 2.49s	remaining: 9.2s
# 213:	learn: 1587.8310941	total: 2.5s	remaining: 9.19s
# 214:	learn: 1586.8776666	total: 2.51s	remaining: 9.17s
# 215:	learn: 1586.4844271	total: 2.52s	remaining: 9.16s
# 216:	learn: 1585.8533844	total: 2.53s	remaining: 9.14s
# 217:	learn: 1585.3259456	total: 2.54s	remaining: 9.13s
# 218:	learn: 1584.8977315	total: 2.56s	remaining: 9.11s
# 219:	learn: 1584.0051994	total: 2.57s	remaining: 9.1s
# 220:	learn: 1583.6213142	total: 2.58s	remaining: 9.08s
# 221:	learn: 1583.3095593	total: 2.59s	remaining: 9.07s
# 222:	learn: 1582.5480582	total: 2.6s	remaining: 9.05s
# 223:	learn: 1582.0116824	total: 2.61s	remaining: 9.04s
# 224:	learn: 1581.5177091	total: 2.62s	remaining: 9.02s
# 225:	learn: 1581.0747050	total: 2.63s	remaining: 9.01s
# 226:	learn: 1580.3026795	total: 2.64s	remaining: 8.99s
# 227:	learn: 1579.7738337	total: 2.65s	remaining: 8.97s
# 228:	learn: 1579.2850076	total: 2.66s	remaining: 8.95s
# 229:	learn: 1578.7502978	total: 2.67s	remaining: 8.94s
# 230:	learn: 1577.9953207	total: 2.68s	remaining: 8.92s
# 231:	learn: 1577.5901017	total: 2.69s	remaining: 8.9s
# 232:	learn: 1576.9197020	total: 2.7s	remaining: 8.89s
# 233:	learn: 1576.6093016	total: 2.71s	remaining: 8.88s
# 234:	learn: 1576.0622658	total: 2.72s	remaining: 8.87s
# 235:	learn: 1575.4676667	total: 2.73s	remaining: 8.85s
# 236:	learn: 1575.0206415	total: 2.75s	remaining: 8.84s
# 237:	learn: 1574.4980180	total: 2.75s	remaining: 8.82s
# 238:	learn: 1574.1129468	total: 2.77s	remaining: 8.81s
# 239:	learn: 1573.4235417	total: 2.78s	remaining: 8.79s
# 240:	learn: 1572.8181829	total: 2.79s	remaining: 8.78s
# 241:	learn: 1572.3201108	total: 2.8s	remaining: 8.77s
# 242:	learn: 1571.7710345	total: 2.81s	remaining: 8.76s
# 243:	learn: 1571.3226709	total: 2.82s	remaining: 8.74s
# 244:	learn: 1570.8459882	total: 2.83s	remaining: 8.72s
# 245:	learn: 1570.4541764	total: 2.84s	remaining: 8.71s
# 246:	learn: 1570.0453136	total: 2.85s	remaining: 8.7s
# 247:	learn: 1569.5727100	total: 2.86s	remaining: 8.68s
# 248:	learn: 1569.0823557	total: 2.87s	remaining: 8.67s
# 249:	learn: 1568.2876149	total: 2.88s	remaining: 8.66s
# 250:	learn: 1568.0979036	total: 2.9s	remaining: 8.65s
# 251:	learn: 1567.6216695	total: 2.91s	remaining: 8.64s
# 252:	learn: 1567.0885935	total: 2.92s	remaining: 8.63s
# 253:	learn: 1566.6979174	total: 2.93s	remaining: 8.62s
# 254:	learn: 1566.0716560	total: 2.94s	remaining: 8.6s
# 255:	learn: 1565.7147790	total: 2.95s	remaining: 8.59s
# 256:	learn: 1565.3254130	total: 2.96s	remaining: 8.57s
# 257:	learn: 1564.7305931	total: 2.98s	remaining: 8.56s
# 258:	learn: 1564.3688468	total: 2.99s	remaining: 8.54s
# 259:	learn: 1563.9634553	total: 3s	remaining: 8.53s
# 260:	learn: 1563.5105843	total: 3.01s	remaining: 8.52s
# 261:	learn: 1563.0651718	total: 3.02s	remaining: 8.51s
# 262:	learn: 1562.5974337	total: 3.03s	remaining: 8.49s
# 263:	learn: 1562.4408732	total: 3.04s	remaining: 8.48s
# 264:	learn: 1561.8767542	total: 3.05s	remaining: 8.46s
# 265:	learn: 1561.4609775	total: 3.06s	remaining: 8.45s
# 266:	learn: 1561.0870885	total: 3.07s	remaining: 8.44s
# 267:	learn: 1560.5682777	total: 3.08s	remaining: 8.42s
# 268:	learn: 1560.2159643	total: 3.09s	remaining: 8.41s
# 269:	learn: 1559.7417869	total: 3.1s	remaining: 8.4s
# 270:	learn: 1559.3337098	total: 3.12s	remaining: 8.38s
# 271:	learn: 1558.7871674	total: 3.13s	remaining: 8.37s
# 272:	learn: 1558.3648658	total: 3.14s	remaining: 8.35s
# 273:	learn: 1558.1455252	total: 3.15s	remaining: 8.34s
# 274:	learn: 1557.6176670	total: 3.16s	remaining: 8.32s
# 275:	learn: 1557.1924427	total: 3.17s	remaining: 8.31s
# 276:	learn: 1556.9615546	total: 3.18s	remaining: 8.3s
# 277:	learn: 1556.2514173	total: 3.19s	remaining: 8.29s
# 278:	learn: 1555.5276645	total: 3.2s	remaining: 8.28s
# 279:	learn: 1555.2013426	total: 3.21s	remaining: 8.26s
# 280:	learn: 1554.6659713	total: 3.23s	remaining: 8.25s
# 281:	learn: 1554.1621287	total: 3.24s	remaining: 8.24s
# 282:	learn: 1553.7467436	total: 3.25s	remaining: 8.23s
# 283:	learn: 1553.4830947	total: 3.26s	remaining: 8.22s
# 284:	learn: 1553.1479817	total: 3.27s	remaining: 8.21s
# 285:	learn: 1552.8702156	total: 3.28s	remaining: 8.19s
# 286:	learn: 1552.3487424	total: 3.29s	remaining: 8.18s
# 287:	learn: 1552.2327930	total: 3.31s	remaining: 8.17s
# 288:	learn: 1551.6203856	total: 3.32s	remaining: 8.16s
# 289:	learn: 1551.3319313	total: 3.33s	remaining: 8.15s
# 290:	learn: 1550.9064961	total: 3.34s	remaining: 8.14s
# 291:	learn: 1550.4180173	total: 3.35s	remaining: 8.13s
# 292:	learn: 1550.2164547	total: 3.36s	remaining: 8.11s
# 293:	learn: 1549.7359730	total: 3.37s	remaining: 8.1s
# 294:	learn: 1549.4055329	total: 3.39s	remaining: 8.09s
# 295:	learn: 1548.9407329	total: 3.4s	remaining: 8.08s
# 296:	learn: 1548.7350317	total: 3.41s	remaining: 8.07s
# 297:	learn: 1548.3311683	total: 3.42s	remaining: 8.06s
# 298:	learn: 1547.9100438	total: 3.43s	remaining: 8.05s
# 299:	learn: 1547.4838699	total: 3.44s	remaining: 8.04s
# 300:	learn: 1547.0706433	total: 3.46s	remaining: 8.03s
# 301:	learn: 1546.4525420	total: 3.47s	remaining: 8.01s
# 302:	learn: 1546.0577252	total: 3.48s	remaining: 8.01s
# 303:	learn: 1545.7361801	total: 3.49s	remaining: 7.99s
# 304:	learn: 1545.0218767	total: 3.5s	remaining: 7.98s
# 305:	learn: 1544.7171464	total: 3.51s	remaining: 7.97s
# 306:	learn: 1544.3114941	total: 3.53s	remaining: 7.96s
# 307:	learn: 1543.8421702	total: 3.54s	remaining: 7.95s
# 308:	learn: 1543.5691006	total: 3.55s	remaining: 7.93s
# 309:	learn: 1542.8483699	total: 3.56s	remaining: 7.92s
# 310:	learn: 1542.5123339	total: 3.57s	remaining: 7.9s
# 311:	learn: 1542.2436261	total: 3.58s	remaining: 7.89s
# 312:	learn: 1541.9198701	total: 3.59s	remaining: 7.87s
# 313:	learn: 1541.4709552	total: 3.6s	remaining: 7.86s
# 314:	learn: 1541.1619797	total: 3.61s	remaining: 7.85s
# 315:	learn: 1541.0304405	total: 3.62s	remaining: 7.83s
# 316:	learn: 1540.6160278	total: 3.63s	remaining: 7.82s
# 317:	learn: 1540.4976645	total: 3.64s	remaining: 7.8s
# 318:	learn: 1540.0379954	total: 3.65s	remaining: 7.79s
# 319:	learn: 1539.6511901	total: 3.66s	remaining: 7.78s
# 320:	learn: 1539.4107695	total: 3.67s	remaining: 7.76s
# 321:	learn: 1538.9911861	total: 3.68s	remaining: 7.75s
# 322:	learn: 1538.8177841	total: 3.69s	remaining: 7.74s
# 323:	learn: 1538.6821135	total: 3.7s	remaining: 7.72s
# 324:	learn: 1538.4912882	total: 3.71s	remaining: 7.71s
# 325:	learn: 1538.0241883	total: 3.72s	remaining: 7.69s
# 326:	learn: 1537.7756681	total: 3.73s	remaining: 7.68s
# 327:	learn: 1537.2197335	total: 3.74s	remaining: 7.67s
# 328:	learn: 1536.9739319	total: 3.75s	remaining: 7.65s
# 329:	learn: 1536.6311158	total: 3.76s	remaining: 7.64s
# 330:	learn: 1536.3772832	total: 3.77s	remaining: 7.63s
# 331:	learn: 1535.9992948	total: 3.78s	remaining: 7.61s
# 332:	learn: 1535.3745671	total: 3.79s	remaining: 7.6s
# 333:	learn: 1534.9414911	total: 3.8s	remaining: 7.59s
# 334:	learn: 1534.4725685	total: 3.81s	remaining: 7.57s
# 335:	learn: 1534.1798170	total: 3.83s	remaining: 7.56s
# 336:	learn: 1533.7805669	total: 3.84s	remaining: 7.55s
# 337:	learn: 1533.4210990	total: 3.85s	remaining: 7.53s
# 338:	learn: 1533.0138991	total: 3.86s	remaining: 7.52s
# 339:	learn: 1532.6134471	total: 3.87s	remaining: 7.51s
# 340:	learn: 1532.1437039	total: 3.88s	remaining: 7.5s
# 341:	learn: 1531.9834259	total: 3.89s	remaining: 7.49s
# 342:	learn: 1531.7960769	total: 3.9s	remaining: 7.47s
# 343:	learn: 1531.4397092	total: 3.91s	remaining: 7.46s
# 344:	learn: 1531.3013227	total: 3.92s	remaining: 7.45s
# 345:	learn: 1530.9913571	total: 3.93s	remaining: 7.43s
# 346:	learn: 1530.8219126	total: 3.94s	remaining: 7.42s
# 347:	learn: 1530.6935942	total: 3.96s	remaining: 7.41s
# 348:	learn: 1530.4139888	total: 3.97s	remaining: 7.4s
# 349:	learn: 1529.8732252	total: 3.98s	remaining: 7.39s
# 350:	learn: 1529.1717124	total: 3.99s	remaining: 7.37s
# 351:	learn: 1528.8124007	total: 4s	remaining: 7.36s
# 352:	learn: 1528.4187574	total: 4.01s	remaining: 7.35s
# 353:	learn: 1528.1914846	total: 4.02s	remaining: 7.34s
# 354:	learn: 1527.9212948	total: 4.03s	remaining: 7.33s
# 355:	learn: 1527.3761950	total: 4.04s	remaining: 7.32s
# 356:	learn: 1526.9058792	total: 4.05s	remaining: 7.3s
# 357:	learn: 1526.6917493	total: 4.07s	remaining: 7.29s
# 358:	learn: 1526.3031630	total: 4.08s	remaining: 7.28s
# 359:	learn: 1525.9806789	total: 4.09s	remaining: 7.27s
# 360:	learn: 1525.4258737	total: 4.1s	remaining: 7.26s
# 361:	learn: 1525.2349634	total: 4.11s	remaining: 7.24s
# 362:	learn: 1524.9380668	total: 4.12s	remaining: 7.23s
# 363:	learn: 1524.6431947	total: 4.13s	remaining: 7.22s
# 364:	learn: 1524.4304616	total: 4.15s	remaining: 7.21s
# 365:	learn: 1524.1383332	total: 4.16s	remaining: 7.2s
# 366:	learn: 1523.4605747	total: 4.17s	remaining: 7.19s
# 367:	learn: 1523.3036968	total: 4.18s	remaining: 7.18s
# 368:	learn: 1522.9607676	total: 4.19s	remaining: 7.17s
# 369:	learn: 1522.6228911	total: 4.2s	remaining: 7.16s
# 370:	learn: 1522.3129267	total: 4.21s	remaining: 7.14s
# 371:	learn: 1521.4727612	total: 4.22s	remaining: 7.13s
# 372:	learn: 1520.4847847	total: 4.23s	remaining: 7.12s
# 373:	learn: 1520.0488068	total: 4.25s	remaining: 7.11s
# 374:	learn: 1519.7111547	total: 4.26s	remaining: 7.1s
# 375:	learn: 1519.3250868	total: 4.27s	remaining: 7.08s
# 376:	learn: 1518.9183064	total: 4.28s	remaining: 7.07s
# 377:	learn: 1518.7445213	total: 4.29s	remaining: 7.06s
# 378:	learn: 1518.4393395	total: 4.3s	remaining: 7.05s
# 379:	learn: 1518.0236248	total: 4.31s	remaining: 7.04s
# 380:	learn: 1517.6259977	total: 4.32s	remaining: 7.03s
# 381:	learn: 1517.3910355	total: 4.34s	remaining: 7.01s
# 382:	learn: 1517.0314423	total: 4.35s	remaining: 7s
# 383:	learn: 1516.6897879	total: 4.36s	remaining: 6.99s
# 384:	learn: 1516.2579927	total: 4.37s	remaining: 6.98s
# 385:	learn: 1515.8138930	total: 4.38s	remaining: 6.97s
# 386:	learn: 1515.5254020	total: 4.39s	remaining: 6.96s
# 387:	learn: 1515.4493605	total: 4.4s	remaining: 6.94s
# 388:	learn: 1515.2285047	total: 4.41s	remaining: 6.93s
# 389:	learn: 1515.0045232	total: 4.42s	remaining: 6.92s
# 390:	learn: 1514.5075238	total: 4.43s	remaining: 6.91s
# 391:	learn: 1514.4154706	total: 4.45s	remaining: 6.9s
# 392:	learn: 1514.1834579	total: 4.46s	remaining: 6.88s
# 393:	learn: 1513.7487263	total: 4.47s	remaining: 6.87s
# 394:	learn: 1513.4991077	total: 4.48s	remaining: 6.86s
# 395:	learn: 1512.9376724	total: 4.49s	remaining: 6.85s
# 396:	learn: 1512.8367325	total: 4.5s	remaining: 6.84s
# 397:	learn: 1512.4276240	total: 4.51s	remaining: 6.82s
# 398:	learn: 1512.1098502	total: 4.52s	remaining: 6.81s
# 399:	learn: 1511.7415974	total: 4.53s	remaining: 6.8s
# 400:	learn: 1511.4286490	total: 4.54s	remaining: 6.79s
# 401:	learn: 1511.1579660	total: 4.55s	remaining: 6.77s
# 402:	learn: 1510.9462192	total: 4.56s	remaining: 6.76s
# 403:	learn: 1510.6010070	total: 4.57s	remaining: 6.75s
# 404:	learn: 1510.2452195	total: 4.58s	remaining: 6.73s
# 405:	learn: 1509.9673518	total: 4.59s	remaining: 6.72s
# 406:	learn: 1509.7272330	total: 4.61s	remaining: 6.71s
# 407:	learn: 1509.4329026	total: 4.62s	remaining: 6.7s
# 408:	learn: 1509.1454796	total: 4.63s	remaining: 6.69s
# 409:	learn: 1508.9128172	total: 4.64s	remaining: 6.67s
# 410:	learn: 1508.5343424	total: 4.65s	remaining: 6.66s
# 411:	learn: 1508.4084752	total: 4.66s	remaining: 6.65s
# 412:	learn: 1507.9497403	total: 4.67s	remaining: 6.64s
# 413:	learn: 1507.6358649	total: 4.68s	remaining: 6.63s
# 414:	learn: 1507.4170448	total: 4.69s	remaining: 6.62s
# 415:	learn: 1507.2267151	total: 4.7s	remaining: 6.6s
# 416:	learn: 1506.8591093	total: 4.71s	remaining: 6.59s
# 417:	learn: 1506.5832816	total: 4.72s	remaining: 6.58s
# 418:	learn: 1506.3712437	total: 4.74s	remaining: 6.57s
# 419:	learn: 1506.1306332	total: 4.75s	remaining: 6.55s
# 420:	learn: 1505.7199447	total: 4.76s	remaining: 6.54s
# 421:	learn: 1505.5288506	total: 4.77s	remaining: 6.53s
# 422:	learn: 1505.1559799	total: 4.78s	remaining: 6.52s
# 423:	learn: 1505.1113211	total: 4.79s	remaining: 6.51s
# 424:	learn: 1504.4723670	total: 4.8s	remaining: 6.5s
# 425:	learn: 1503.9815453	total: 4.81s	remaining: 6.48s
# 426:	learn: 1503.7418224	total: 4.82s	remaining: 6.47s
# 427:	learn: 1503.3740908	total: 4.83s	remaining: 6.46s
# 428:	learn: 1503.2102007	total: 4.84s	remaining: 6.45s
# 429:	learn: 1503.0408581	total: 4.85s	remaining: 6.43s
# 430:	learn: 1502.7278122	total: 4.87s	remaining: 6.42s
# 431:	learn: 1502.3000573	total: 4.88s	remaining: 6.41s
# 432:	learn: 1501.9740155	total: 4.89s	remaining: 6.4s
# 433:	learn: 1501.8372432	total: 4.9s	remaining: 6.39s
# 434:	learn: 1501.3967375	total: 4.91s	remaining: 6.38s
# 435:	learn: 1501.0319951	total: 4.92s	remaining: 6.37s
# 436:	learn: 1500.6717752	total: 4.93s	remaining: 6.35s
# 437:	learn: 1500.5132758	total: 4.94s	remaining: 6.34s
# 438:	learn: 1500.2194198	total: 4.95s	remaining: 6.33s
# 439:	learn: 1499.8609845	total: 4.96s	remaining: 6.32s
# 440:	learn: 1499.6372410	total: 4.97s	remaining: 6.31s
# 441:	learn: 1499.5137855	total: 4.99s	remaining: 6.29s
# 442:	learn: 1499.3758804	total: 5s	remaining: 6.28s
# 443:	learn: 1499.0612518	total: 5.01s	remaining: 6.27s
# 444:	learn: 1498.7932905	total: 5.02s	remaining: 6.26s
# 445:	learn: 1498.7834005	total: 5.03s	remaining: 6.25s
# 446:	learn: 1498.3784301	total: 5.04s	remaining: 6.24s
# 447:	learn: 1498.1314218	total: 5.06s	remaining: 6.23s
# 448:	learn: 1497.9575534	total: 5.07s	remaining: 6.22s
# 449:	learn: 1497.8175449	total: 5.08s	remaining: 6.21s
# 450:	learn: 1497.4762274	total: 5.09s	remaining: 6.2s
# 451:	learn: 1497.2869621	total: 5.1s	remaining: 6.19s
# 452:	learn: 1497.2157453	total: 5.11s	remaining: 6.17s
# 453:	learn: 1496.9876742	total: 5.12s	remaining: 6.16s
# 454:	learn: 1496.7149674	total: 5.13s	remaining: 6.15s
# 455:	learn: 1496.4444374	total: 5.15s	remaining: 6.14s
# 456:	learn: 1496.1918176	total: 5.16s	remaining: 6.13s
# 457:	learn: 1495.9689599	total: 5.17s	remaining: 6.12s
# 458:	learn: 1495.8060873	total: 5.18s	remaining: 6.11s
# 459:	learn: 1495.6176177	total: 5.19s	remaining: 6.09s
# 460:	learn: 1495.3838260	total: 5.2s	remaining: 6.08s
# 461:	learn: 1494.9362761	total: 5.21s	remaining: 6.07s
# 462:	learn: 1494.5363864	total: 5.22s	remaining: 6.06s
# 463:	learn: 1494.3299585	total: 5.23s	remaining: 6.05s
# 464:	learn: 1494.1070998	total: 5.25s	remaining: 6.04s
# 465:	learn: 1494.0264605	total: 5.26s	remaining: 6.02s
# 466:	learn: 1493.7675236	total: 5.27s	remaining: 6.01s
# 467:	learn: 1493.4778984	total: 5.28s	remaining: 6s
# 468:	learn: 1493.2399691	total: 5.29s	remaining: 5.99s
# 469:	learn: 1492.9979867	total: 5.3s	remaining: 5.98s
# 470:	learn: 1492.5790935	total: 5.31s	remaining: 5.96s
# 471:	learn: 1492.2324361	total: 5.32s	remaining: 5.95s
# 472:	learn: 1491.9891592	total: 5.33s	remaining: 5.94s
# 473:	learn: 1491.7302467	total: 5.34s	remaining: 5.93s
# 474:	learn: 1491.5663320	total: 5.36s	remaining: 5.92s
# 475:	learn: 1491.4399233	total: 5.37s	remaining: 5.91s
# 476:	learn: 1491.1994746	total: 5.38s	remaining: 5.9s
# 477:	learn: 1490.9562377	total: 5.39s	remaining: 5.89s
# 478:	learn: 1490.7024594	total: 5.4s	remaining: 5.88s
# 479:	learn: 1490.5192427	total: 5.41s	remaining: 5.86s
# 480:	learn: 1490.2395499	total: 5.42s	remaining: 5.85s
# 481:	learn: 1489.9874660	total: 5.44s	remaining: 5.84s
# 482:	learn: 1489.8447691	total: 5.45s	remaining: 5.83s
# 483:	learn: 1489.6333529	total: 5.46s	remaining: 5.82s
# 484:	learn: 1489.4611799	total: 5.47s	remaining: 5.8s
# 485:	learn: 1489.1061367	total: 5.48s	remaining: 5.79s
# 486:	learn: 1488.8183471	total: 5.49s	remaining: 5.78s
# 487:	learn: 1488.5389586	total: 5.5s	remaining: 5.77s
# 488:	learn: 1488.2339437	total: 5.51s	remaining: 5.76s
# 489:	learn: 1487.8254772	total: 5.52s	remaining: 5.74s
# 490:	learn: 1487.5525479	total: 5.53s	remaining: 5.73s
# 491:	learn: 1487.1879078	total: 5.54s	remaining: 5.72s
# 492:	learn: 1486.9675155	total: 5.55s	remaining: 5.71s
# 493:	learn: 1486.6509441	total: 5.56s	remaining: 5.7s
# 494:	learn: 1486.4981940	total: 5.57s	remaining: 5.68s
# 495:	learn: 1486.4238392	total: 5.58s	remaining: 5.67s
# 496:	learn: 1486.1984310	total: 5.59s	remaining: 5.66s
# 497:	learn: 1485.9935695	total: 5.6s	remaining: 5.65s
# 498:	learn: 1485.7077231	total: 5.61s	remaining: 5.64s
# 499:	learn: 1485.4723686	total: 5.63s	remaining: 5.63s
# 500:	learn: 1485.2373298	total: 5.64s	remaining: 5.61s
# 501:	learn: 1485.0623712	total: 5.65s	remaining: 5.6s
# 502:	learn: 1484.7662358	total: 5.66s	remaining: 5.59s
# 503:	learn: 1484.6194047	total: 5.67s	remaining: 5.58s
# 504:	learn: 1484.4116955	total: 5.68s	remaining: 5.57s
# 505:	learn: 1484.1672618	total: 5.69s	remaining: 5.55s
# 506:	learn: 1483.9342748	total: 5.7s	remaining: 5.54s
# 507:	learn: 1483.8451018	total: 5.71s	remaining: 5.53s
# 508:	learn: 1483.5140631	total: 5.72s	remaining: 5.52s
# 509:	learn: 1483.3143154	total: 5.73s	remaining: 5.51s
# 510:	learn: 1483.0822632	total: 5.75s	remaining: 5.5s
# 511:	learn: 1483.0243401	total: 5.75s	remaining: 5.49s
# 512:	learn: 1482.6648067	total: 5.77s	remaining: 5.47s
# 513:	learn: 1482.5690062	total: 5.78s	remaining: 5.46s
# 514:	learn: 1482.3330251	total: 5.79s	remaining: 5.45s
# 515:	learn: 1482.1069982	total: 5.8s	remaining: 5.44s
# 516:	learn: 1481.7593089	total: 5.81s	remaining: 5.43s
# 517:	learn: 1481.4924842	total: 5.82s	remaining: 5.42s
# 518:	learn: 1481.1934734	total: 5.83s	remaining: 5.4s
# 519:	learn: 1480.9438171	total: 5.84s	remaining: 5.39s
# 520:	learn: 1480.7530565	total: 5.85s	remaining: 5.38s
# 521:	learn: 1480.5908694	total: 5.86s	remaining: 5.37s
# 522:	learn: 1480.4088067	total: 5.87s	remaining: 5.36s
# 523:	learn: 1480.1960724	total: 5.88s	remaining: 5.34s
# 524:	learn: 1480.0272332	total: 5.89s	remaining: 5.33s
# 525:	learn: 1479.8034329	total: 5.9s	remaining: 5.32s
# 526:	learn: 1479.4509941	total: 5.91s	remaining: 5.31s
# 527:	learn: 1479.2208692	total: 5.92s	remaining: 5.29s
# 528:	learn: 1479.1169898	total: 5.93s	remaining: 5.28s
# 529:	learn: 1478.7046096	total: 5.94s	remaining: 5.27s
# 530:	learn: 1478.6033649	total: 5.95s	remaining: 5.26s
# 531:	learn: 1478.4321440	total: 5.96s	remaining: 5.25s
# 532:	learn: 1478.1790474	total: 5.97s	remaining: 5.24s
# 533:	learn: 1478.1132936	total: 5.99s	remaining: 5.22s
# 534:	learn: 1477.9776737	total: 6s	remaining: 5.21s
# 535:	learn: 1477.6473906	total: 6.01s	remaining: 5.2s
# 536:	learn: 1477.3319425	total: 6.02s	remaining: 5.19s
# 537:	learn: 1477.2606192	total: 6.03s	remaining: 5.18s
# 538:	learn: 1477.1170968	total: 6.04s	remaining: 5.16s
# 539:	learn: 1476.6972062	total: 6.05s	remaining: 5.15s
# 540:	learn: 1476.5513427	total: 6.06s	remaining: 5.14s
# 541:	learn: 1476.2935675	total: 6.07s	remaining: 5.13s
# 542:	learn: 1476.2606436	total: 6.08s	remaining: 5.12s
# 543:	learn: 1476.1172434	total: 6.09s	remaining: 5.11s
# 544:	learn: 1475.8329863	total: 6.1s	remaining: 5.09s
# 545:	learn: 1475.6196634	total: 6.11s	remaining: 5.08s
# 546:	learn: 1475.3843699	total: 6.13s	remaining: 5.07s
# 547:	learn: 1475.2105746	total: 6.14s	remaining: 5.06s
# 548:	learn: 1474.9900628	total: 6.15s	remaining: 5.05s
# 549:	learn: 1474.7802968	total: 6.16s	remaining: 5.04s
# 550:	learn: 1474.5503997	total: 6.17s	remaining: 5.03s
# 551:	learn: 1473.9773030	total: 6.18s	remaining: 5.02s
# 552:	learn: 1473.7261919	total: 6.19s	remaining: 5.01s
# 553:	learn: 1473.4779138	total: 6.2s	remaining: 4.99s
# 554:	learn: 1473.2016345	total: 6.21s	remaining: 4.98s
# 555:	learn: 1472.7614224	total: 6.22s	remaining: 4.97s
# 556:	learn: 1472.4784590	total: 6.23s	remaining: 4.96s
# 557:	learn: 1472.2062502	total: 6.25s	remaining: 4.95s
# 558:	learn: 1471.8767421	total: 6.26s	remaining: 4.94s
# 559:	learn: 1471.8211685	total: 6.27s	remaining: 4.92s
# 560:	learn: 1471.5739914	total: 6.28s	remaining: 4.91s
# 561:	learn: 1471.5442612	total: 6.29s	remaining: 4.9s
# 562:	learn: 1471.2503462	total: 6.3s	remaining: 4.89s
# 563:	learn: 1471.0370401	total: 6.31s	remaining: 4.88s
# 564:	learn: 1470.9191865	total: 6.32s	remaining: 4.87s
# 565:	learn: 1470.8023061	total: 6.33s	remaining: 4.85s
# 566:	learn: 1470.3129479	total: 6.34s	remaining: 4.84s
# 567:	learn: 1470.0867550	total: 6.35s	remaining: 4.83s
# 568:	learn: 1469.8833948	total: 6.36s	remaining: 4.82s
# 569:	learn: 1469.4657723	total: 6.37s	remaining: 4.81s
# 570:	learn: 1469.1650857	total: 6.38s	remaining: 4.79s
# 571:	learn: 1468.9939781	total: 6.39s	remaining: 4.78s
# 572:	learn: 1468.6023365	total: 6.41s	remaining: 4.77s
# 573:	learn: 1468.2429834	total: 6.42s	remaining: 4.76s
# 574:	learn: 1468.0293135	total: 6.42s	remaining: 4.75s
# 575:	learn: 1467.8111100	total: 6.44s	remaining: 4.74s
# 576:	learn: 1467.5556281	total: 6.45s	remaining: 4.72s
# 577:	learn: 1467.2927216	total: 6.46s	remaining: 4.71s
# 578:	learn: 1467.0300867	total: 6.47s	remaining: 4.7s
# 579:	learn: 1466.7956787	total: 6.48s	remaining: 4.69s
# 580:	learn: 1466.5015121	total: 6.49s	remaining: 4.68s
# 581:	learn: 1466.1660982	total: 6.5s	remaining: 4.67s
# 582:	learn: 1465.9739099	total: 6.51s	remaining: 4.66s
# 583:	learn: 1465.8153078	total: 6.52s	remaining: 4.64s
# 584:	learn: 1465.6776449	total: 6.53s	remaining: 4.63s
# 585:	learn: 1465.4557045	total: 6.54s	remaining: 4.62s
# 586:	learn: 1465.0726187	total: 6.55s	remaining: 4.61s
# 587:	learn: 1464.8198892	total: 6.56s	remaining: 4.6s
# 588:	learn: 1464.5753477	total: 6.58s	remaining: 4.59s
# 589:	learn: 1464.4596308	total: 6.59s	remaining: 4.58s
# 590:	learn: 1464.1897497	total: 6.6s	remaining: 4.57s
# 591:	learn: 1464.0705314	total: 6.61s	remaining: 4.55s
# 592:	learn: 1463.8294969	total: 6.62s	remaining: 4.54s
# 593:	learn: 1463.7404995	total: 6.63s	remaining: 4.53s
# 594:	learn: 1463.5334220	total: 6.64s	remaining: 4.52s
# 595:	learn: 1463.4215351	total: 6.65s	remaining: 4.51s
# 596:	learn: 1463.1769612	total: 6.66s	remaining: 4.5s
# 597:	learn: 1462.9663577	total: 6.67s	remaining: 4.49s
# 598:	learn: 1462.6610503	total: 6.68s	remaining: 4.47s
# 599:	learn: 1462.4523595	total: 6.69s	remaining: 4.46s
# 600:	learn: 1462.2197968	total: 6.71s	remaining: 4.45s
# 601:	learn: 1461.8537543	total: 6.71s	remaining: 4.44s
# 602:	learn: 1461.6357919	total: 6.73s	remaining: 4.43s
# 603:	learn: 1461.4746251	total: 6.74s	remaining: 4.42s
# 604:	learn: 1461.2665410	total: 6.75s	remaining: 4.41s
# 605:	learn: 1461.0727042	total: 6.76s	remaining: 4.4s
# 606:	learn: 1461.0213641	total: 6.77s	remaining: 4.38s
# 607:	learn: 1460.7821172	total: 6.78s	remaining: 4.37s
# 608:	learn: 1460.3619077	total: 6.79s	remaining: 4.36s
# 609:	learn: 1460.0647491	total: 6.8s	remaining: 4.35s
# 610:	learn: 1459.8049694	total: 6.81s	remaining: 4.34s
# 611:	learn: 1459.6657282	total: 6.82s	remaining: 4.33s
# 612:	learn: 1459.4303400	total: 6.83s	remaining: 4.32s
# 613:	learn: 1459.2202440	total: 6.85s	remaining: 4.3s
# 614:	learn: 1458.8623621	total: 6.86s	remaining: 4.29s
# 615:	learn: 1458.5734168	total: 6.87s	remaining: 4.28s
# 616:	learn: 1458.3271486	total: 6.88s	remaining: 4.27s
# 617:	learn: 1458.1385401	total: 6.89s	remaining: 4.26s
# 618:	learn: 1457.8589468	total: 6.9s	remaining: 4.25s
# 619:	learn: 1457.6188311	total: 6.91s	remaining: 4.24s
# 620:	learn: 1457.5127053	total: 6.92s	remaining: 4.22s
# 621:	learn: 1457.2747673	total: 6.93s	remaining: 4.21s
# 622:	learn: 1457.1700596	total: 6.94s	remaining: 4.2s
# 623:	learn: 1456.7852552	total: 6.95s	remaining: 4.19s
# 624:	learn: 1456.5218276	total: 6.96s	remaining: 4.18s
# 625:	learn: 1456.3982428	total: 6.97s	remaining: 4.17s
# 626:	learn: 1455.9695180	total: 6.98s	remaining: 4.16s
# 627:	learn: 1455.7812136	total: 7s	remaining: 4.14s
# 628:	learn: 1455.5326320	total: 7.01s	remaining: 4.13s
# 629:	learn: 1455.2589900	total: 7.02s	remaining: 4.12s
# 630:	learn: 1455.0662182	total: 7.03s	remaining: 4.11s
# 631:	learn: 1454.9119068	total: 7.04s	remaining: 4.1s
# 632:	learn: 1454.6109021	total: 7.05s	remaining: 4.09s
# 633:	learn: 1454.4873167	total: 7.06s	remaining: 4.08s
# 634:	learn: 1454.3327527	total: 7.07s	remaining: 4.06s
# 635:	learn: 1454.3056508	total: 7.08s	remaining: 4.05s
# 636:	learn: 1454.1094571	total: 7.09s	remaining: 4.04s
# 637:	learn: 1453.9248167	total: 7.1s	remaining: 4.03s
# 638:	learn: 1453.6356880	total: 7.11s	remaining: 4.02s
# 639:	learn: 1453.4934528	total: 7.13s	remaining: 4.01s
# 640:	learn: 1453.2397722	total: 7.14s	remaining: 4s
# 641:	learn: 1453.0902425	total: 7.15s	remaining: 3.99s
# 642:	learn: 1452.9184959	total: 7.16s	remaining: 3.98s
# 643:	learn: 1452.7543570	total: 7.18s	remaining: 3.97s
# 644:	learn: 1452.6739897	total: 7.19s	remaining: 3.96s
# 645:	learn: 1452.5262106	total: 7.2s	remaining: 3.94s
# 646:	learn: 1452.2807889	total: 7.21s	remaining: 3.93s
# 647:	learn: 1452.1654673	total: 7.22s	remaining: 3.92s
# 648:	learn: 1452.0168497	total: 7.23s	remaining: 3.91s
# 649:	learn: 1451.7599246	total: 7.24s	remaining: 3.9s
# 650:	learn: 1451.6065569	total: 7.25s	remaining: 3.89s
# 651:	learn: 1451.3417633	total: 7.26s	remaining: 3.87s
# 652:	learn: 1451.2891403	total: 7.27s	remaining: 3.86s
# 653:	learn: 1451.1239696	total: 7.28s	remaining: 3.85s
# 654:	learn: 1450.8627939	total: 7.29s	remaining: 3.84s
# 655:	learn: 1450.4968575	total: 7.3s	remaining: 3.83s
# 656:	learn: 1450.3950639	total: 7.31s	remaining: 3.82s
# 657:	learn: 1450.2190850	total: 7.32s	remaining: 3.81s
# 658:	learn: 1449.9036146	total: 7.33s	remaining: 3.79s
# 659:	learn: 1449.8070100	total: 7.34s	remaining: 3.78s
# 660:	learn: 1449.6715154	total: 7.35s	remaining: 3.77s
# 661:	learn: 1449.4752002	total: 7.37s	remaining: 3.76s
# 662:	learn: 1449.3121248	total: 7.38s	remaining: 3.75s
# 663:	learn: 1449.1610040	total: 7.39s	remaining: 3.74s
# 664:	learn: 1448.9578942	total: 7.4s	remaining: 3.73s
# 665:	learn: 1448.4502645	total: 7.41s	remaining: 3.71s
# 666:	learn: 1448.1573236	total: 7.42s	remaining: 3.7s
# 667:	learn: 1447.7778330	total: 7.43s	remaining: 3.69s
# 668:	learn: 1447.6826153	total: 7.44s	remaining: 3.68s
# 669:	learn: 1447.4944955	total: 7.45s	remaining: 3.67s
# 670:	learn: 1447.4141117	total: 7.46s	remaining: 3.66s
# 671:	learn: 1447.2517129	total: 7.47s	remaining: 3.65s
# 672:	learn: 1447.0824597	total: 7.49s	remaining: 3.64s
# 673:	learn: 1446.9203996	total: 7.5s	remaining: 3.63s
# 674:	learn: 1446.5820927	total: 7.51s	remaining: 3.61s
# 675:	learn: 1446.4077193	total: 7.52s	remaining: 3.6s
# 676:	learn: 1446.1913520	total: 7.53s	remaining: 3.59s
# 677:	learn: 1445.8744375	total: 7.54s	remaining: 3.58s
# 678:	learn: 1445.5754631	total: 7.55s	remaining: 3.57s
# 679:	learn: 1445.4203621	total: 7.56s	remaining: 3.56s
# 680:	learn: 1445.2196139	total: 7.58s	remaining: 3.55s
# 681:	learn: 1445.1588328	total: 7.59s	remaining: 3.54s
# 682:	learn: 1444.9715191	total: 7.6s	remaining: 3.53s
# 683:	learn: 1444.7683529	total: 7.61s	remaining: 3.52s
# 684:	learn: 1444.6152512	total: 7.62s	remaining: 3.5s
# 685:	learn: 1444.4994793	total: 7.63s	remaining: 3.49s
# 686:	learn: 1444.1937565	total: 7.64s	remaining: 3.48s
# 687:	learn: 1444.0286985	total: 7.66s	remaining: 3.47s
# 688:	learn: 1443.8883023	total: 7.67s	remaining: 3.46s
# 689:	learn: 1443.5994955	total: 7.68s	remaining: 3.45s
# 690:	learn: 1443.4243038	total: 7.69s	remaining: 3.44s
# 691:	learn: 1443.2453906	total: 7.7s	remaining: 3.43s
# 692:	learn: 1443.0699182	total: 7.71s	remaining: 3.42s
# 693:	learn: 1442.7647589	total: 7.72s	remaining: 3.4s
# 694:	learn: 1442.5436363	total: 7.74s	remaining: 3.39s
# 695:	learn: 1442.4713737	total: 7.75s	remaining: 3.38s
# 696:	learn: 1442.1717214	total: 7.76s	remaining: 3.37s
# 697:	learn: 1441.8983454	total: 7.77s	remaining: 3.36s
# 698:	learn: 1441.7745523	total: 7.78s	remaining: 3.35s
# 699:	learn: 1441.6137717	total: 7.79s	remaining: 3.34s
# 700:	learn: 1441.3004933	total: 7.8s	remaining: 3.33s
# 701:	learn: 1441.1602610	total: 7.82s	remaining: 3.32s
# 702:	learn: 1440.9083805	total: 7.83s	remaining: 3.31s
# 703:	learn: 1440.6325204	total: 7.84s	remaining: 3.29s
# 704:	learn: 1440.4236287	total: 7.85s	remaining: 3.28s
# 705:	learn: 1440.2363941	total: 7.86s	remaining: 3.27s
# 706:	learn: 1440.0336807	total: 7.87s	remaining: 3.26s
# 707:	learn: 1439.8447423	total: 7.88s	remaining: 3.25s
# 708:	learn: 1439.6976062	total: 7.89s	remaining: 3.24s
# 709:	learn: 1439.5786217	total: 7.9s	remaining: 3.23s
# 710:	learn: 1439.5256946	total: 7.92s	remaining: 3.22s
# 711:	learn: 1439.3861799	total: 7.93s	remaining: 3.21s
# 712:	learn: 1439.1780452	total: 7.94s	remaining: 3.19s
# 713:	learn: 1438.9431438	total: 7.95s	remaining: 3.18s
# 714:	learn: 1438.7935030	total: 7.96s	remaining: 3.17s
# 715:	learn: 1438.4709783	total: 7.97s	remaining: 3.16s
# 716:	learn: 1438.4146715	total: 7.98s	remaining: 3.15s
# 717:	learn: 1438.2629878	total: 7.99s	remaining: 3.14s
# 718:	learn: 1437.8887853	total: 8s	remaining: 3.13s
# 719:	learn: 1437.8018394	total: 8.01s	remaining: 3.12s
# 720:	learn: 1437.5689159	total: 8.02s	remaining: 3.1s
# 721:	learn: 1437.4120038	total: 8.03s	remaining: 3.09s
# 722:	learn: 1437.3661280	total: 8.04s	remaining: 3.08s
# 723:	learn: 1437.2885428	total: 8.06s	remaining: 3.07s
# 724:	learn: 1437.1535908	total: 8.07s	remaining: 3.06s
# 725:	learn: 1436.8612906	total: 8.08s	remaining: 3.05s
# 726:	learn: 1436.6774971	total: 8.09s	remaining: 3.04s
# 727:	learn: 1436.5484550	total: 8.1s	remaining: 3.02s
# 728:	learn: 1436.4221027	total: 8.11s	remaining: 3.01s
# 729:	learn: 1436.2611871	total: 8.12s	remaining: 3s
# 730:	learn: 1436.1099726	total: 8.13s	remaining: 2.99s
# 731:	learn: 1435.9572403	total: 8.14s	remaining: 2.98s
# 732:	learn: 1435.8788268	total: 8.15s	remaining: 2.97s
# 733:	learn: 1435.6840586	total: 8.16s	remaining: 2.96s
# 734:	learn: 1435.4933033	total: 8.17s	remaining: 2.95s
# 735:	learn: 1435.2976473	total: 8.18s	remaining: 2.94s
# 736:	learn: 1435.1971232	total: 8.19s	remaining: 2.92s
# 737:	learn: 1434.8954478	total: 8.2s	remaining: 2.91s
# 738:	learn: 1434.8069080	total: 8.21s	remaining: 2.9s
# 739:	learn: 1434.6249490	total: 8.22s	remaining: 2.89s
# 740:	learn: 1434.5478998	total: 8.23s	remaining: 2.88s
# 741:	learn: 1434.4968967	total: 8.24s	remaining: 2.87s
# 742:	learn: 1434.3659902	total: 8.26s	remaining: 2.85s
# 743:	learn: 1434.1024592	total: 8.27s	remaining: 2.84s
# 744:	learn: 1434.0257393	total: 8.28s	remaining: 2.83s
# 745:	learn: 1433.9844443	total: 8.29s	remaining: 2.82s
# 746:	learn: 1433.8543364	total: 8.3s	remaining: 2.81s
# 747:	learn: 1433.5540482	total: 8.31s	remaining: 2.8s
# 748:	learn: 1433.3864640	total: 8.32s	remaining: 2.79s
# 749:	learn: 1433.1592226	total: 8.33s	remaining: 2.78s
# 750:	learn: 1433.0228085	total: 8.34s	remaining: 2.76s
# 751:	learn: 1432.7725709	total: 8.35s	remaining: 2.75s
# 752:	learn: 1432.3727916	total: 8.36s	remaining: 2.74s
# 753:	learn: 1432.1699346	total: 8.37s	remaining: 2.73s
# 754:	learn: 1432.0249877	total: 8.38s	remaining: 2.72s
# 755:	learn: 1431.7893533	total: 8.39s	remaining: 2.71s
# 756:	learn: 1431.6967234	total: 8.4s	remaining: 2.7s
# 757:	learn: 1431.4746238	total: 8.41s	remaining: 2.69s
# 758:	learn: 1431.3404174	total: 8.43s	remaining: 2.67s
# 759:	learn: 1431.0340756	total: 8.44s	remaining: 2.66s
# 760:	learn: 1430.8403347	total: 8.45s	remaining: 2.65s
# 761:	learn: 1430.7148857	total: 8.46s	remaining: 2.64s
# 762:	learn: 1430.4982363	total: 8.47s	remaining: 2.63s
# 763:	learn: 1430.2935091	total: 8.48s	remaining: 2.62s
# 764:	learn: 1430.2002966	total: 8.49s	remaining: 2.61s
# 765:	learn: 1429.7894112	total: 8.5s	remaining: 2.6s
# 766:	learn: 1429.5809908	total: 8.51s	remaining: 2.58s
# 767:	learn: 1429.4824011	total: 8.52s	remaining: 2.57s
# 768:	learn: 1429.4429585	total: 8.53s	remaining: 2.56s
# 769:	learn: 1429.2162137	total: 8.55s	remaining: 2.55s
# 770:	learn: 1428.8106052	total: 8.56s	remaining: 2.54s
# 771:	learn: 1428.5802831	total: 8.57s	remaining: 2.53s
# 772:	learn: 1428.4910105	total: 8.58s	remaining: 2.52s
# 773:	learn: 1428.3839330	total: 8.59s	remaining: 2.51s
# 774:	learn: 1428.1755802	total: 8.6s	remaining: 2.5s
# 775:	learn: 1428.0640439	total: 8.61s	remaining: 2.48s
# 776:	learn: 1427.9769210	total: 8.62s	remaining: 2.47s
# 777:	learn: 1427.8312099	total: 8.63s	remaining: 2.46s
# 778:	learn: 1427.5769033	total: 8.64s	remaining: 2.45s
# 779:	learn: 1427.4506463	total: 8.65s	remaining: 2.44s
# 780:	learn: 1427.2005324	total: 8.66s	remaining: 2.43s
# 781:	learn: 1427.0015078	total: 8.67s	remaining: 2.42s
# 782:	learn: 1426.7405828	total: 8.68s	remaining: 2.41s
# 783:	learn: 1426.6103937	total: 8.69s	remaining: 2.4s
# 784:	learn: 1426.5077185	total: 8.7s	remaining: 2.38s
# 785:	learn: 1426.1838722	total: 8.71s	remaining: 2.37s
# 786:	learn: 1426.0620372	total: 8.72s	remaining: 2.36s
# 787:	learn: 1426.0001953	total: 8.73s	remaining: 2.35s
# 788:	learn: 1425.8602571	total: 8.74s	remaining: 2.34s
# 789:	learn: 1425.6878993	total: 8.76s	remaining: 2.33s
# 790:	learn: 1425.5371350	total: 8.77s	remaining: 2.32s
# 791:	learn: 1425.3178631	total: 8.78s	remaining: 2.3s
# 792:	learn: 1424.8618647	total: 8.78s	remaining: 2.29s
# 793:	learn: 1424.5507849	total: 8.79s	remaining: 2.28s
# 794:	learn: 1424.4087547	total: 8.8s	remaining: 2.27s
# 795:	learn: 1424.2730871	total: 8.81s	remaining: 2.26s
# 796:	learn: 1424.0944397	total: 8.82s	remaining: 2.25s
# 797:	learn: 1424.0098889	total: 8.83s	remaining: 2.24s
# 798:	learn: 1423.8514906	total: 8.84s	remaining: 2.23s
# 799:	learn: 1423.6876360	total: 8.85s	remaining: 2.21s
# 800:	learn: 1423.6287945	total: 8.87s	remaining: 2.2s
# 801:	learn: 1423.4881813	total: 8.88s	remaining: 2.19s
# 802:	learn: 1423.3280454	total: 8.89s	remaining: 2.18s
# 803:	learn: 1422.8762950	total: 8.9s	remaining: 2.17s
# 804:	learn: 1422.6219167	total: 8.91s	remaining: 2.16s
# 805:	learn: 1422.5197652	total: 8.92s	remaining: 2.15s
# 806:	learn: 1422.3472004	total: 8.93s	remaining: 2.13s
# 807:	learn: 1422.1254174	total: 8.94s	remaining: 2.12s
# 808:	learn: 1421.7722427	total: 8.95s	remaining: 2.11s
# 809:	learn: 1421.6537933	total: 8.96s	remaining: 2.1s
# 810:	learn: 1421.5424082	total: 8.97s	remaining: 2.09s
# 811:	learn: 1421.5001644	total: 8.98s	remaining: 2.08s
# 812:	learn: 1421.4603605	total: 8.99s	remaining: 2.07s
# 813:	learn: 1421.3187530	total: 9s	remaining: 2.06s
# 814:	learn: 1421.1048045	total: 9.01s	remaining: 2.04s
# 815:	learn: 1420.9648908	total: 9.02s	remaining: 2.03s
# 816:	learn: 1420.7254723	total: 9.03s	remaining: 2.02s
# 817:	learn: 1420.6649082	total: 9.04s	remaining: 2.01s
# 818:	learn: 1420.3859785	total: 9.06s	remaining: 2s
# 819:	learn: 1420.2860801	total: 9.07s	remaining: 1.99s
# 820:	learn: 1420.1485109	total: 9.08s	remaining: 1.98s
# 821:	learn: 1419.9717842	total: 9.09s	remaining: 1.97s
# 822:	learn: 1419.8376684	total: 9.1s	remaining: 1.96s
# 823:	learn: 1419.6296877	total: 9.11s	remaining: 1.95s
# 824:	learn: 1419.4837176	total: 9.12s	remaining: 1.93s
# 825:	learn: 1419.3132446	total: 9.13s	remaining: 1.92s
# 826:	learn: 1419.1785904	total: 9.14s	remaining: 1.91s
# 827:	learn: 1419.0708653	total: 9.15s	remaining: 1.9s
# 828:	learn: 1419.0025293	total: 9.16s	remaining: 1.89s
# 829:	learn: 1418.7707041	total: 9.17s	remaining: 1.88s
# 830:	learn: 1418.5703721	total: 9.18s	remaining: 1.87s
# 831:	learn: 1418.4104103	total: 9.19s	remaining: 1.86s
# 832:	learn: 1418.1942722	total: 9.2s	remaining: 1.84s
# 833:	learn: 1418.0348079	total: 9.21s	remaining: 1.83s
# 834:	learn: 1417.9491857	total: 9.22s	remaining: 1.82s
# 835:	learn: 1417.8150534	total: 9.23s	remaining: 1.81s
# 836:	learn: 1417.6436830	total: 9.24s	remaining: 1.8s
# 837:	learn: 1417.5165363	total: 9.26s	remaining: 1.79s
# 838:	learn: 1417.3895612	total: 9.27s	remaining: 1.78s
# 839:	learn: 1417.1953766	total: 9.28s	remaining: 1.77s
# 840:	learn: 1417.1406406	total: 9.29s	remaining: 1.75s
# 841:	learn: 1416.9720401	total: 9.3s	remaining: 1.74s
# 842:	learn: 1416.8933694	total: 9.31s	remaining: 1.73s
# 843:	learn: 1416.7401678	total: 9.32s	remaining: 1.72s
# 844:	learn: 1416.6111120	total: 9.33s	remaining: 1.71s
# 845:	learn: 1416.3186040	total: 9.34s	remaining: 1.7s
# 846:	learn: 1416.2290076	total: 9.35s	remaining: 1.69s
# 847:	learn: 1416.0135040	total: 9.36s	remaining: 1.68s
# 848:	learn: 1415.8197251	total: 9.37s	remaining: 1.67s
# 849:	learn: 1415.5553272	total: 9.38s	remaining: 1.66s
# 850:	learn: 1415.3996358	total: 9.39s	remaining: 1.64s
# 851:	learn: 1415.3004974	total: 9.4s	remaining: 1.63s
# 852:	learn: 1415.1696714	total: 9.41s	remaining: 1.62s
# 853:	learn: 1414.9827763	total: 9.43s	remaining: 1.61s
# 854:	learn: 1414.7731538	total: 9.44s	remaining: 1.6s
# 855:	learn: 1414.5982871	total: 9.45s	remaining: 1.59s
# 856:	learn: 1414.3664749	total: 9.46s	remaining: 1.58s
# 857:	learn: 1414.2639023	total: 9.47s	remaining: 1.57s
# 858:	learn: 1414.1873729	total: 9.48s	remaining: 1.55s
# 859:	learn: 1414.0372061	total: 9.49s	remaining: 1.54s
# 860:	learn: 1414.0064183	total: 9.5s	remaining: 1.53s
# 861:	learn: 1413.9576354	total: 9.51s	remaining: 1.52s
# 862:	learn: 1413.8952789	total: 9.52s	remaining: 1.51s
# 863:	learn: 1413.7658528	total: 9.53s	remaining: 1.5s
# 864:	learn: 1413.5426891	total: 9.54s	remaining: 1.49s
# 865:	learn: 1413.4610534	total: 9.55s	remaining: 1.48s
# 866:	learn: 1413.2745723	total: 9.56s	remaining: 1.47s
# 867:	learn: 1413.1589676	total: 9.57s	remaining: 1.46s
# 868:	learn: 1413.1452302	total: 9.59s	remaining: 1.44s
# 869:	learn: 1412.9304546	total: 9.6s	remaining: 1.43s
# 870:	learn: 1412.6658842	total: 9.6s	remaining: 1.42s
# 871:	learn: 1412.4208853	total: 9.61s	remaining: 1.41s
# 872:	learn: 1412.2683530	total: 9.62s	remaining: 1.4s
# 873:	learn: 1412.1219306	total: 9.63s	remaining: 1.39s
# 874:	learn: 1411.9313550	total: 9.64s	remaining: 1.38s
# 875:	learn: 1411.8491393	total: 9.66s	remaining: 1.37s
# 876:	learn: 1411.6189196	total: 9.67s	remaining: 1.35s
# 877:	learn: 1411.4480509	total: 9.68s	remaining: 1.34s
# 878:	learn: 1411.3108302	total: 9.69s	remaining: 1.33s
# 879:	learn: 1411.1218715	total: 9.7s	remaining: 1.32s
# 880:	learn: 1410.9878106	total: 9.71s	remaining: 1.31s
# 881:	learn: 1410.8441342	total: 9.72s	remaining: 1.3s
# 882:	learn: 1410.8153966	total: 9.73s	remaining: 1.29s
# 883:	learn: 1410.6105894	total: 9.74s	remaining: 1.28s
# 884:	learn: 1410.4581963	total: 9.75s	remaining: 1.27s
# 885:	learn: 1410.3129483	total: 9.77s	remaining: 1.26s
# 886:	learn: 1410.0745601	total: 9.78s	remaining: 1.25s
# 887:	learn: 1409.8525674	total: 9.79s	remaining: 1.23s
# 888:	learn: 1409.6773018	total: 9.8s	remaining: 1.22s
# 889:	learn: 1409.5628306	total: 9.81s	remaining: 1.21s
# 890:	learn: 1409.4251404	total: 9.82s	remaining: 1.2s
# 891:	learn: 1409.3742800	total: 9.83s	remaining: 1.19s
# 892:	learn: 1409.2134167	total: 9.84s	remaining: 1.18s
# 893:	learn: 1408.9741321	total: 9.85s	remaining: 1.17s
# 894:	learn: 1408.7760487	total: 9.86s	remaining: 1.16s
# 895:	learn: 1408.6289378	total: 9.87s	remaining: 1.15s
# 896:	learn: 1408.4792499	total: 9.88s	remaining: 1.13s
# 897:	learn: 1408.3047143	total: 9.89s	remaining: 1.12s
# 898:	learn: 1408.1999761	total: 9.9s	remaining: 1.11s
# 899:	learn: 1408.0578776	total: 9.91s	remaining: 1.1s
# 900:	learn: 1407.9416808	total: 9.92s	remaining: 1.09s
# 901:	learn: 1407.8011822	total: 9.94s	remaining: 1.08s
# 902:	learn: 1407.7020034	total: 9.95s	remaining: 1.07s
# 903:	learn: 1407.5477398	total: 9.96s	remaining: 1.06s
# 904:	learn: 1407.3304247	total: 9.96s	remaining: 1.05s
# 905:	learn: 1407.2318703	total: 9.98s	remaining: 1.03s
# 906:	learn: 1407.1264485	total: 9.99s	remaining: 1.02s
# 907:	learn: 1407.0401492	total: 10s	remaining: 1.01s
# 908:	learn: 1406.8475518	total: 10s	remaining: 1s
# 909:	learn: 1406.6208081	total: 10s	remaining: 991ms
# 910:	learn: 1406.4269607	total: 10s	remaining: 980ms
# 911:	learn: 1406.3477944	total: 10s	remaining: 969ms
# 912:	learn: 1406.2133494	total: 10s	remaining: 958ms
# 913:	learn: 1406.1081669	total: 10.1s	remaining: 947ms
# 914:	learn: 1405.9566471	total: 10.1s	remaining: 936ms
# 915:	learn: 1405.8375280	total: 10.1s	remaining: 925ms
# 916:	learn: 1405.7095619	total: 10.1s	remaining: 914ms
# 917:	learn: 1405.6005819	total: 10.1s	remaining: 903ms
# 918:	learn: 1405.4834358	total: 10.1s	remaining: 892ms
# 919:	learn: 1405.3230939	total: 10.1s	remaining: 881ms
# 920:	learn: 1404.8977472	total: 10.1s	remaining: 869ms
# 921:	learn: 1404.8078410	total: 10.1s	remaining: 858ms
# 922:	learn: 1404.6529968	total: 10.2s	remaining: 847ms
# 923:	learn: 1404.5652736	total: 10.2s	remaining: 836ms
# 924:	learn: 1404.3029455	total: 10.2s	remaining: 825ms
# 925:	learn: 1404.2934867	total: 10.2s	remaining: 814ms
# 926:	learn: 1404.2736403	total: 10.2s	remaining: 803ms
# 927:	learn: 1404.1343097	total: 10.2s	remaining: 792ms
# 928:	learn: 1403.9846145	total: 10.2s	remaining: 781ms
# 929:	learn: 1403.8291552	total: 10.2s	remaining: 770ms
# 930:	learn: 1403.6769511	total: 10.2s	remaining: 759ms
# 931:	learn: 1403.5841177	total: 10.3s	remaining: 748ms
# 932:	learn: 1403.4965052	total: 10.3s	remaining: 737ms
# 933:	learn: 1403.3488790	total: 10.3s	remaining: 726ms
# 934:	learn: 1403.2253397	total: 10.3s	remaining: 715ms
# 935:	learn: 1403.0152730	total: 10.3s	remaining: 704ms
# 936:	learn: 1403.0140369	total: 10.3s	remaining: 693ms
# 937:	learn: 1402.7691580	total: 10.3s	remaining: 682ms
# 938:	learn: 1402.6483178	total: 10.3s	remaining: 671ms
# 939:	learn: 1402.4805084	total: 10.3s	remaining: 660ms
# 940:	learn: 1402.2660609	total: 10.4s	remaining: 649ms
# 941:	learn: 1402.0783011	total: 10.4s	remaining: 638ms
# 942:	learn: 1401.9063871	total: 10.4s	remaining: 627ms
# 943:	learn: 1401.7676715	total: 10.4s	remaining: 616ms
# 944:	learn: 1401.5607330	total: 10.4s	remaining: 605ms
# 945:	learn: 1401.4781745	total: 10.4s	remaining: 594ms
# 946:	learn: 1401.3487001	total: 10.4s	remaining: 583ms
# 947:	learn: 1401.2334792	total: 10.4s	remaining: 572ms
# 948:	learn: 1401.1199027	total: 10.4s	remaining: 561ms
# 949:	learn: 1401.0343864	total: 10.4s	remaining: 550ms
# 950:	learn: 1400.6989611	total: 10.5s	remaining: 539ms
# 951:	learn: 1400.5918620	total: 10.5s	remaining: 528ms
# 952:	learn: 1400.4714170	total: 10.5s	remaining: 517ms
# 953:	learn: 1400.3168451	total: 10.5s	remaining: 506ms
# 954:	learn: 1400.2222166	total: 10.5s	remaining: 495ms
# 955:	learn: 1400.0953906	total: 10.5s	remaining: 484ms
# 956:	learn: 1399.9144048	total: 10.5s	remaining: 473ms
# 957:	learn: 1399.8283343	total: 10.5s	remaining: 462ms
# 958:	learn: 1399.6864924	total: 10.5s	remaining: 451ms
# 959:	learn: 1399.5775968	total: 10.6s	remaining: 440ms
# 960:	learn: 1399.5310283	total: 10.6s	remaining: 429ms
# 961:	learn: 1399.3961835	total: 10.6s	remaining: 418ms
# 962:	learn: 1399.2954183	total: 10.6s	remaining: 407ms
# 963:	learn: 1399.0081511	total: 10.6s	remaining: 396ms
# 964:	learn: 1398.8956938	total: 10.6s	remaining: 385ms
# 965:	learn: 1398.8023324	total: 10.6s	remaining: 374ms
# 966:	learn: 1398.7031143	total: 10.6s	remaining: 363ms
# 967:	learn: 1398.5040679	total: 10.6s	remaining: 352ms
# 968:	learn: 1398.3804870	total: 10.6s	remaining: 341ms
# 969:	learn: 1398.2505295	total: 10.7s	remaining: 330ms
# 970:	learn: 1398.0520675	total: 10.7s	remaining: 319ms
# 971:	learn: 1397.9423472	total: 10.7s	remaining: 308ms
# 972:	learn: 1397.8573369	total: 10.7s	remaining: 297ms
# 973:	learn: 1397.7719568	total: 10.7s	remaining: 286ms
# 974:	learn: 1397.6340218	total: 10.7s	remaining: 275ms
# 975:	learn: 1397.4680077	total: 10.7s	remaining: 264ms
# 976:	learn: 1397.2628974	total: 10.7s	remaining: 253ms
# 977:	learn: 1397.0332596	total: 10.7s	remaining: 242ms
# 978:	learn: 1396.9043186	total: 10.8s	remaining: 231ms
# 979:	learn: 1396.7654644	total: 10.8s	remaining: 220ms
# 980:	learn: 1396.6524931	total: 10.8s	remaining: 209ms
# 981:	learn: 1396.4703387	total: 10.8s	remaining: 198ms
# 982:	learn: 1396.3377110	total: 10.8s	remaining: 187ms
# 983:	learn: 1396.1270049	total: 10.8s	remaining: 176ms
# 984:	learn: 1395.9935456	total: 10.8s	remaining: 165ms
# 985:	learn: 1395.7659582	total: 10.8s	remaining: 154ms
# 986:	learn: 1395.5404560	total: 10.8s	remaining: 143ms
# 987:	learn: 1395.2564054	total: 10.8s	remaining: 132ms
# 988:	learn: 1395.1594540	total: 10.9s	remaining: 121ms
# 989:	learn: 1395.0031413	total: 10.9s	remaining: 110ms
# 990:	learn: 1394.9145312	total: 10.9s	remaining: 98.8ms
# 991:	learn: 1394.7415385	total: 10.9s	remaining: 87.8ms
# 992:	learn: 1394.5302240	total: 10.9s	remaining: 76.8ms
# 993:	learn: 1394.3942073	total: 10.9s	remaining: 65.8ms
# 994:	learn: 1394.1836278	total: 10.9s	remaining: 54.9ms
# 995:	learn: 1394.1245771	total: 10.9s	remaining: 43.9ms
# 996:	learn: 1393.9305984	total: 10.9s	remaining: 32.9ms
# 997:	learn: 1393.7916531	total: 10.9s	remaining: 21.9ms
# 998:	learn: 1393.6574664	total: 11s	remaining: 11ms
# 999:	learn: 1393.5707823	total: 11s	remaining: 0us
# 1600.8283408621046
# {'iterations': 1000, 'learning_rate': 0.5}
# CPU times: total: 2min 13s
# Wall time: 8min 53s

# %%
# %%time
model = XGBRegressor(random_state=42)
parameters = {'n_estimators': [300], 'learning_rate': [.1, .5]}
best_xgb = teach_model(model, parameters, train_features, train_target,time_list)
# Out:
# 1630.4270808784722
# {'learning_rate': 0.5, 'n_estimators': 300}
# CPU times: total: 13min 2s
# Wall time: 8min 53s

# %%
# %%time
model = LGBMRegressor(random_state=42)
parameters = {'learning_rate': [.1, .5], 'n_estimators': [200, 300]}
best_lgbm = teach_model(model, parameters, train_features, train_target,time_list)
# Out:
# 1630.7690475975978
# {'learning_rate': 0.5, 'n_estimators': 300}
# CPU times: total: 13.9 s
# Wall time: 29.8 s

# %%
scaler = StandardScaler()
scaler.fit(train_features)
train_features_lr = scaler.transform(train_features)
test_features_lr = scaler.transform(test_features)

# %%
# %%time
model = LinearRegression()
parameters = {}
best_lr = teach_model(model, parameters, train_features_lr, train_target,time_list)
# Out:
# 2611.7659238523506
# {}
# CPU times: total: 12.9 s
# Wall time: 13.6 s

# %%
pd.DataFrame(columns=['mean_learning_time (sec)', 'mean_fit_time (sec)','RMSE'],
             index=['DecisionTree', 'CatBoost', 'XGBoost', 'LGBM', 'LinearRegression'],
             data=time_list)
# Out:
#                   mean_learning_time (sec)  mean_fit_time (sec)         RMSE
# DecisionTree                      8.312959             0.977289  2348.016873
# CatBoost                         12.740075             0.062414  1600.828341
# XGBoost                         473.194270             1.002954  1630.427081
# LGBM                             16.397260             2.147541  1630.769048
# LinearRegression                  9.821678             0.038061  2611.765924

# %% [markdown]
# Среди всех моделей наилучшую метрику имеет `CatBoostRegressor`, но его обучение заняло в среднем 12.
# В то же время модель `DecisionTree` показала метрику сильно хуже , чем `CatBoostRegressor`, но справилась с этим за 8 секунд.
# Модель `CatBoostRegressor` также имеет наилучший показатель времени предсказания среди остальных моделей
#
# Так как заказчику важно и время обучения модели, время предсказания модели, и качество предсказания, то можно выбрать одну из двух моделей основываясь на превалирующем факторе заказчика.
#
# Для продолжения получения результата остановимся на том, что `CatBoost` "выиграл" в двух из трёх требований среди остальных моделей\
# Отсюда наилучшей моделью выбираем - `CatBoostRegressor`

# %%
prediction = best_cb.predict(test_features)

# %% [markdown]
# Посчитаем `RMSE` модели на тестовой выборке:

# %%
mean_squared_error(test_target, prediction)**.5
# Out:
# 1588.1545466977434

# %% [markdown]
# Получаем, что наилучшая модель `CatBoostRegressor` ошибается в среднем на +- 1588 евро.

# %% [markdown]
# # Проверка модели на адекватность

# %%
dummy = DummyRegressor()
dummy.fit(train_features, train_target)
dummy_predict = dummy.predict(test_features)

mean_squared_error(test_target, dummy_predict)**.5
# Out:
# 4525.640795884502

# %% [markdown]
# Метрика модели `CatBoostRegressor` почти в 3 раза меньше метрики константной модели, что показывает адекватность обученной модели `CatBoostRegressor`

# %% [markdown]
# # Вывод

# %% [markdown]
# Опираясь на проведённый анализ можно подытожить:
#  - [x] Потенциальные требования заказчика удовлетворены ( Скорость обучения модели, точность предсказания)
#  - [x] Модель проходит проверку на адекватность, что говорит о необходимости использования ML в данной задаче
#  - Наилучшая модель по качеству предсказания - `CatBoostRegressor`
#  - Наилучшая модель по скорости предсказания(учитывая адекватное качество) - `LGBMRegressor`
